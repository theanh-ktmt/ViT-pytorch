# %%
# %cd ..
# !pwd
# Out:
# /remote/vast0/tran/workspace/ViT-pytorch
# /remote/vast0/tran/workspace/ViT-pytorch

# %%
# !bash scripts/train.sh
# Out:
# 03/20/2025 19:26:04 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 03/20/2025 19:26:06 - INFO - __main__ - classifier: token
# hidden_size: 768
# patches:
#   size: !!python/tuple
#   - 16
#   - 16
# representation_size: null
# transformer:
#   attention_dropout_rate: 0.0
#   dropout_rate: 0.1
#   mlp_dim: 3072
#   num_heads: 12
#   num_layers: 12
#
# 03/20/2025 19:26:06 - INFO - __main__ - Training parameters Namespace(name='baseline', dataset='hymenoptera', model_type='ViT-B_16', pretrained_dir='checkpoint/ViT-B_16.npz', output_dir='output/baseline', img_size=224, train_batch_size=1024, eval_batch_size=1024, eval_every=100, learning_rate=0.03, weight_decay=0, num_steps=100, decay_type='cosine', warmup_steps=10, max_grad_norm=1.0, local_rank=-1, seed=42, gradient_accumulation_steps=1, fp16=False, fp16_opt_level='O2', loss_scale=0, k_fold=5, do_test=False, n_gpu=1, device=device(type='cuda'))
# 03/20/2025 19:26:06 - INFO - __main__ - Total Parameter: 	85.8M
# 85.800194
# VisionTransformer(
#   (transformer): Transformer(
#     (embeddings): Embeddings(
#       (patch_embeddings): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x Block(
#           (attention_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (ffn_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (ffn): Mlp(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (attn): Attention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (out): Linear(in_features=768, out_features=768, bias=True)
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (proj_dropout): Dropout(p=0.0, inplace=False)
#             (softmax): Softmax(dim=-1)
#           )
#         )
#       )
#       (encoder_norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#     )
#   )
#   (head): Linear(in_features=768, out_features=2, bias=True)
# )
# 03/20/2025 19:26:06 - INFO - __main__ - ***** Running training *****
# 03/20/2025 19:26:06 - INFO - __main__ -   Total optimization steps = 100
# 03/20/2025 19:26:06 - INFO - __main__ -   Instantaneous batch size per GPU = 1024
# 03/20/2025 19:26:06 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1024
# 03/20/2025 19:26:06 - INFO - __main__ -   Gradient Accumulation steps = 1
# 03/20/2025 19:26:06 - INFO - __main__ - Training fold: 1 / 5
# Training (1 / 100 Steps) (loss=0.69315):   0%|| 0/1 [00:01<?, ?it/s]/home/tran/miniconda3/envs/vit/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:384: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   _warn_get_lr_called_within_step(self)
# Training (1 / 100 Steps) (loss=0.69315): 100%|| 1/1 [00:02<00:00,  2.03s/it]
# Training (2 / 100 Steps) (loss=0.69315): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (3 / 100 Steps) (loss=0.68730): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (4 / 100 Steps) (loss=0.67081): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (5 / 100 Steps) (loss=0.64116): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (6 / 100 Steps) (loss=0.59811): 100%|| 1/1 [00:01<00:00,  1.42s/it]
# Training (7 / 100 Steps) (loss=0.53768): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (8 / 100 Steps) (loss=0.46727): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (9 / 100 Steps) (loss=0.39177): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (10 / 100 Steps) (loss=0.32773): 100%|| 1/1 [00:01<00:00,  1.42s/it]
# Training (11 / 100 Steps) (loss=0.26193): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (12 / 100 Steps) (loss=0.20744): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (13 / 100 Steps) (loss=0.18600): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (14 / 100 Steps) (loss=0.14777): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (15 / 100 Steps) (loss=0.13119): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (16 / 100 Steps) (loss=0.10457): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (17 / 100 Steps) (loss=0.10487): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (18 / 100 Steps) (loss=0.09957): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (19 / 100 Steps) (loss=0.09488): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (20 / 100 Steps) (loss=0.08288): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (21 / 100 Steps) (loss=0.10445): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (22 / 100 Steps) (loss=0.06124): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (23 / 100 Steps) (loss=0.08647): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (24 / 100 Steps) (loss=0.06323): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (25 / 100 Steps) (loss=0.06719): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (26 / 100 Steps) (loss=0.06044): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (27 / 100 Steps) (loss=0.05781): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (28 / 100 Steps) (loss=0.07030): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (29 / 100 Steps) (loss=0.08222): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (30 / 100 Steps) (loss=0.06370): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (31 / 100 Steps) (loss=0.06217): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (32 / 100 Steps) (loss=0.06268): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (33 / 100 Steps) (loss=0.06908): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (34 / 100 Steps) (loss=0.04266): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (35 / 100 Steps) (loss=0.07651): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (36 / 100 Steps) (loss=0.06703): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (37 / 100 Steps) (loss=0.05872): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (38 / 100 Steps) (loss=0.04906): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (39 / 100 Steps) (loss=0.08160): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (40 / 100 Steps) (loss=0.07896): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (41 / 100 Steps) (loss=0.05273): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (42 / 100 Steps) (loss=0.05482): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (43 / 100 Steps) (loss=0.03715): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (44 / 100 Steps) (loss=0.03674): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (45 / 100 Steps) (loss=0.04008): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (46 / 100 Steps) (loss=0.06080): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (47 / 100 Steps) (loss=0.07878): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (48 / 100 Steps) (loss=0.06855): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (49 / 100 Steps) (loss=0.07198): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (50 / 100 Steps) (loss=0.08292): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (51 / 100 Steps) (loss=0.05606): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (52 / 100 Steps) (loss=0.06012): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (53 / 100 Steps) (loss=0.05921): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (54 / 100 Steps) (loss=0.04508): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (55 / 100 Steps) (loss=0.05550): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (56 / 100 Steps) (loss=0.06743): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (57 / 100 Steps) (loss=0.05365): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (58 / 100 Steps) (loss=0.05625): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (59 / 100 Steps) (loss=0.05958): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (60 / 100 Steps) (loss=0.05053): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (61 / 100 Steps) (loss=0.05823): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (62 / 100 Steps) (loss=0.08326): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (63 / 100 Steps) (loss=0.05671): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (64 / 100 Steps) (loss=0.06643): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (65 / 100 Steps) (loss=0.03976): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (66 / 100 Steps) (loss=0.04427): 100%|| 1/1 [00:01<00:00,  1.47s/it]
# Training (67 / 100 Steps) (loss=0.05189): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (68 / 100 Steps) (loss=0.07036): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (69 / 100 Steps) (loss=0.06488): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (70 / 100 Steps) (loss=0.04820): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (71 / 100 Steps) (loss=0.07093): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (72 / 100 Steps) (loss=0.04150): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (73 / 100 Steps) (loss=0.07098): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (74 / 100 Steps) (loss=0.04369): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (75 / 100 Steps) (loss=0.05679): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (76 / 100 Steps) (loss=0.07127): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (77 / 100 Steps) (loss=0.04245): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (78 / 100 Steps) (loss=0.04951): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (79 / 100 Steps) (loss=0.06971): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (80 / 100 Steps) (loss=0.04549): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (81 / 100 Steps) (loss=0.05718): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (82 / 100 Steps) (loss=0.08374): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (83 / 100 Steps) (loss=0.10080): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (84 / 100 Steps) (loss=0.06100): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (85 / 100 Steps) (loss=0.04299): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (86 / 100 Steps) (loss=0.06700): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (87 / 100 Steps) (loss=0.04908): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (88 / 100 Steps) (loss=0.05624): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (89 / 100 Steps) (loss=0.06097): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (90 / 100 Steps) (loss=0.06616): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (91 / 100 Steps) (loss=0.04619): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (92 / 100 Steps) (loss=0.08112): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (93 / 100 Steps) (loss=0.06709): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (94 / 100 Steps) (loss=0.06147): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (95 / 100 Steps) (loss=0.04575): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (96 / 100 Steps) (loss=0.06932): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (97 / 100 Steps) (loss=0.06651): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (98 / 100 Steps) (loss=0.07002): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (99 / 100 Steps) (loss=0.05668): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (100 / 100 Steps) (loss=0.09397):   0%|| 0/1 [00:01<?, ?it/s]03/20/2025 19:28:38 - INFO - __main__ - ***** Running Validation *****
# 03/20/2025 19:28:38 - INFO - __main__ -   Num steps = 1
# 03/20/2025 19:28:38 - INFO - __main__ -   Batch size = 1024
#
# Validating... (loss=X.X):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.05072):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.05072): 100%|| 1/1 [00:00<00:00,  2.03it/s]
# 03/20/2025 19:28:38 - INFO - __main__ -
#
# 03/20/2025 19:28:38 - INFO - __main__ - Validation Results
# 03/20/2025 19:28:38 - INFO - __main__ - Global Steps: 100
# 03/20/2025 19:28:38 - INFO - __main__ - Valid Loss: 0.05072
# 03/20/2025 19:28:38 - INFO - __main__ - Valid Accuracy: 0.97917
# 03/20/2025 19:28:39 - INFO - __main__ - Saved model checkpoint to [DIR: output/baseline]
# 03/20/2025 19:28:39 - INFO - __main__ - Best model saved at output/baseline/baseline_fold0_checkpoint.bin
# 03/20/2025 19:28:39 - INFO - __main__ - Update best loss from inf to 0.050716
# 03/20/2025 19:28:39 - INFO - __main__ - Update best accuracy from 0.000000 to 0.979167
# Training (100 / 100 Steps) (loss=0.09397):   0%|| 0/1 [00:02<?, ?it/s]
# 03/20/2025 19:28:39 - INFO - __main__ - Best Accuracy: 	0.979167
# 03/20/2025 19:28:39 - INFO - __main__ - Best Loss: 	0.050716
# 03/20/2025 19:28:39 - INFO - __main__ - Done training fold 1
# 03/20/2025 19:28:39 - INFO - __main__ - ===================================
# 03/20/2025 19:28:39 - INFO - __main__ - Training fold: 2 / 5
# Training (1 / 100 Steps) (loss=0.05486): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (2 / 100 Steps) (loss=0.08336): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (3 / 100 Steps) (loss=0.04426): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (4 / 100 Steps) (loss=0.09074): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (5 / 100 Steps) (loss=0.06204): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (6 / 100 Steps) (loss=0.05989): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (7 / 100 Steps) (loss=0.05778): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (8 / 100 Steps) (loss=0.05005): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (9 / 100 Steps) (loss=0.08394): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (10 / 100 Steps) (loss=0.05248): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (11 / 100 Steps) (loss=0.08268): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (12 / 100 Steps) (loss=0.07067): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (13 / 100 Steps) (loss=0.06758): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (14 / 100 Steps) (loss=0.05335): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (15 / 100 Steps) (loss=0.05538): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (16 / 100 Steps) (loss=0.08784): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (17 / 100 Steps) (loss=0.04239): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (18 / 100 Steps) (loss=0.08429): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (19 / 100 Steps) (loss=0.05855): 100%|| 1/1 [00:01<00:00,  1.43s/it]
# Training (20 / 100 Steps) (loss=0.06915): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (21 / 100 Steps) (loss=0.05987): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (22 / 100 Steps) (loss=0.06878): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (23 / 100 Steps) (loss=0.04917): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (24 / 100 Steps) (loss=0.06694): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (25 / 100 Steps) (loss=0.07749): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (26 / 100 Steps) (loss=0.04554): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (27 / 100 Steps) (loss=0.06034): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (28 / 100 Steps) (loss=0.05562): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (29 / 100 Steps) (loss=0.08973): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (30 / 100 Steps) (loss=0.05445): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (31 / 100 Steps) (loss=0.06024): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (32 / 100 Steps) (loss=0.05880): 100%|| 1/1 [00:01<00:00,  1.47s/it]
# Training (33 / 100 Steps) (loss=0.04342): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (34 / 100 Steps) (loss=0.07256): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (35 / 100 Steps) (loss=0.05102): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (36 / 100 Steps) (loss=0.04456): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (37 / 100 Steps) (loss=0.05505): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (38 / 100 Steps) (loss=0.06334): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (39 / 100 Steps) (loss=0.05449): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (40 / 100 Steps) (loss=0.05876): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (41 / 100 Steps) (loss=0.10566): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (42 / 100 Steps) (loss=0.04911): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (43 / 100 Steps) (loss=0.04246): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (44 / 100 Steps) (loss=0.05866): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (45 / 100 Steps) (loss=0.04099): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (46 / 100 Steps) (loss=0.04905): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (47 / 100 Steps) (loss=0.05090): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (48 / 100 Steps) (loss=0.05783): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (49 / 100 Steps) (loss=0.07096): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (50 / 100 Steps) (loss=0.04477): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (51 / 100 Steps) (loss=0.06559): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (52 / 100 Steps) (loss=0.07491): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (53 / 100 Steps) (loss=0.06197): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (54 / 100 Steps) (loss=0.05470): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (55 / 100 Steps) (loss=0.05301): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (56 / 100 Steps) (loss=0.08223): 100%|| 1/1 [00:01<00:00,  1.47s/it]
# Training (57 / 100 Steps) (loss=0.04769): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (58 / 100 Steps) (loss=0.05340): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (59 / 100 Steps) (loss=0.06590): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (60 / 100 Steps) (loss=0.06638): 100%|| 1/1 [00:01<00:00,  1.65s/it]
# Training (61 / 100 Steps) (loss=0.04289): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (62 / 100 Steps) (loss=0.03732): 100%|| 1/1 [00:01<00:00,  1.71s/it]
# Training (63 / 100 Steps) (loss=0.05728): 100%|| 1/1 [00:01<00:00,  1.66s/it]
# Training (64 / 100 Steps) (loss=0.06062): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (65 / 100 Steps) (loss=0.04999): 100%|| 1/1 [00:01<00:00,  1.66s/it]
# Training (66 / 100 Steps) (loss=0.04730): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (67 / 100 Steps) (loss=0.07102): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (68 / 100 Steps) (loss=0.05067): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (69 / 100 Steps) (loss=0.05441): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (70 / 100 Steps) (loss=0.05061): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (71 / 100 Steps) (loss=0.06196): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (72 / 100 Steps) (loss=0.06313): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (73 / 100 Steps) (loss=0.05181): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (74 / 100 Steps) (loss=0.04208): 100%|| 1/1 [00:01<00:00,  1.66s/it]
# Training (75 / 100 Steps) (loss=0.06562): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (76 / 100 Steps) (loss=0.04727): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (77 / 100 Steps) (loss=0.04690): 100%|| 1/1 [00:01<00:00,  1.66s/it]
# Training (78 / 100 Steps) (loss=0.05970): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (79 / 100 Steps) (loss=0.06970): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (80 / 100 Steps) (loss=0.07310): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (81 / 100 Steps) (loss=0.09280): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (82 / 100 Steps) (loss=0.04928): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (83 / 100 Steps) (loss=0.04621): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (84 / 100 Steps) (loss=0.04429): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (85 / 100 Steps) (loss=0.03769): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (86 / 100 Steps) (loss=0.05643): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (87 / 100 Steps) (loss=0.04370): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (88 / 100 Steps) (loss=0.05719): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (89 / 100 Steps) (loss=0.05852): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (90 / 100 Steps) (loss=0.06226): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (91 / 100 Steps) (loss=0.03261): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (92 / 100 Steps) (loss=0.04710): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (93 / 100 Steps) (loss=0.05634): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (94 / 100 Steps) (loss=0.06078): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (95 / 100 Steps) (loss=0.06606): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (96 / 100 Steps) (loss=0.05422): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (97 / 100 Steps) (loss=0.04347): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (98 / 100 Steps) (loss=0.05786): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (99 / 100 Steps) (loss=0.07060): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (100 / 100 Steps) (loss=0.05266):   0%|| 0/1 [00:01<?, ?it/s]03/20/2025 19:31:13 - INFO - __main__ - ***** Running Validation *****
# 03/20/2025 19:31:13 - INFO - __main__ -   Num steps = 1
# 03/20/2025 19:31:13 - INFO - __main__ -   Batch size = 1024
#
# Validating... (loss=X.X):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.08389):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.08389): 100%|| 1/1 [00:00<00:00,  2.07it/s]
# 03/20/2025 19:31:13 - INFO - __main__ -
#
# 03/20/2025 19:31:13 - INFO - __main__ - Validation Results
# 03/20/2025 19:31:13 - INFO - __main__ - Global Steps: 100
# 03/20/2025 19:31:13 - INFO - __main__ - Valid Loss: 0.08389
# 03/20/2025 19:31:13 - INFO - __main__ - Valid Accuracy: 0.95833
# 03/20/2025 19:31:14 - INFO - __main__ - Saved model checkpoint to [DIR: output/baseline]
# 03/20/2025 19:31:14 - INFO - __main__ - Best model saved at output/baseline/baseline_fold1_checkpoint.bin
# 03/20/2025 19:31:14 - INFO - __main__ - Update best loss from inf to 0.083886
# 03/20/2025 19:31:14 - INFO - __main__ - Update best accuracy from 0.000000 to 0.958333
# Training (100 / 100 Steps) (loss=0.05266):   0%|| 0/1 [00:02<?, ?it/s]
# 03/20/2025 19:31:14 - INFO - __main__ - Best Accuracy: 	0.958333
# 03/20/2025 19:31:14 - INFO - __main__ - Best Loss: 	0.083886
# 03/20/2025 19:31:14 - INFO - __main__ - Done training fold 2
# 03/20/2025 19:31:14 - INFO - __main__ - ===================================
# 03/20/2025 19:31:14 - INFO - __main__ - Training fold: 3 / 5
# Training (1 / 100 Steps) (loss=0.04390): 100%|| 1/1 [00:01<00:00,  1.63s/it]
# Training (2 / 100 Steps) (loss=0.03865): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (3 / 100 Steps) (loss=0.03728): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (4 / 100 Steps) (loss=0.04594): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (5 / 100 Steps) (loss=0.10056): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (6 / 100 Steps) (loss=0.05391): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (7 / 100 Steps) (loss=0.03092): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (8 / 100 Steps) (loss=0.04349): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (9 / 100 Steps) (loss=0.03619): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (10 / 100 Steps) (loss=0.06183): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (11 / 100 Steps) (loss=0.03669): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (12 / 100 Steps) (loss=0.03629): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (13 / 100 Steps) (loss=0.05648): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (14 / 100 Steps) (loss=0.05335): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (15 / 100 Steps) (loss=0.03460): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (16 / 100 Steps) (loss=0.07867): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (17 / 100 Steps) (loss=0.06749): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (18 / 100 Steps) (loss=0.05495): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (19 / 100 Steps) (loss=0.03535): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (20 / 100 Steps) (loss=0.05297): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (21 / 100 Steps) (loss=0.03543): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (22 / 100 Steps) (loss=0.02355): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (23 / 100 Steps) (loss=0.02638): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (24 / 100 Steps) (loss=0.03535): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (25 / 100 Steps) (loss=0.05493): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (26 / 100 Steps) (loss=0.03771): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (27 / 100 Steps) (loss=0.04005): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (28 / 100 Steps) (loss=0.04092): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (29 / 100 Steps) (loss=0.02974): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (30 / 100 Steps) (loss=0.04380): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (31 / 100 Steps) (loss=0.02981): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (32 / 100 Steps) (loss=0.04129): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (33 / 100 Steps) (loss=0.03539): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (34 / 100 Steps) (loss=0.03705): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (35 / 100 Steps) (loss=0.05199): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (36 / 100 Steps) (loss=0.04523): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (37 / 100 Steps) (loss=0.04797): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (38 / 100 Steps) (loss=0.03701): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (39 / 100 Steps) (loss=0.05904): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (40 / 100 Steps) (loss=0.03070): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (41 / 100 Steps) (loss=0.03686): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (42 / 100 Steps) (loss=0.07604): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (43 / 100 Steps) (loss=0.04835): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (44 / 100 Steps) (loss=0.05950): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (45 / 100 Steps) (loss=0.03910): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (46 / 100 Steps) (loss=0.06347): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (47 / 100 Steps) (loss=0.02628): 100%|| 1/1 [00:01<00:00,  1.65s/it]
# Training (48 / 100 Steps) (loss=0.03301): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (49 / 100 Steps) (loss=0.05046): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (50 / 100 Steps) (loss=0.05674): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (51 / 100 Steps) (loss=0.03983): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (52 / 100 Steps) (loss=0.05195): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (53 / 100 Steps) (loss=0.05634): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (54 / 100 Steps) (loss=0.05379): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (55 / 100 Steps) (loss=0.07857): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (56 / 100 Steps) (loss=0.03334): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (57 / 100 Steps) (loss=0.03215): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (58 / 100 Steps) (loss=0.03804): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (59 / 100 Steps) (loss=0.03186): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (60 / 100 Steps) (loss=0.03972): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (61 / 100 Steps) (loss=0.03524): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (62 / 100 Steps) (loss=0.04558): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (63 / 100 Steps) (loss=0.04285): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (64 / 100 Steps) (loss=0.04081): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (65 / 100 Steps) (loss=0.04761): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (66 / 100 Steps) (loss=0.03710): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (67 / 100 Steps) (loss=0.03510): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (68 / 100 Steps) (loss=0.03512): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (69 / 100 Steps) (loss=0.03309): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (70 / 100 Steps) (loss=0.05629): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (71 / 100 Steps) (loss=0.05280): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (72 / 100 Steps) (loss=0.04367): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (73 / 100 Steps) (loss=0.02120): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (74 / 100 Steps) (loss=0.04039): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (75 / 100 Steps) (loss=0.03958): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (76 / 100 Steps) (loss=0.05631): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (77 / 100 Steps) (loss=0.03046): 100%|| 1/1 [00:01<00:00,  1.70s/it]
# Training (78 / 100 Steps) (loss=0.03462): 100%|| 1/1 [00:01<00:00,  1.64s/it]
# Training (79 / 100 Steps) (loss=0.03950): 100%|| 1/1 [00:01<00:00,  1.67s/it]
# Training (80 / 100 Steps) (loss=0.04942): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (81 / 100 Steps) (loss=0.03178): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (82 / 100 Steps) (loss=0.05223): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (83 / 100 Steps) (loss=0.05294): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (84 / 100 Steps) (loss=0.05891): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (85 / 100 Steps) (loss=0.05615): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (86 / 100 Steps) (loss=0.03879): 100%|| 1/1 [00:01<00:00,  1.68s/it]
# Training (87 / 100 Steps) (loss=0.03219): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (88 / 100 Steps) (loss=0.04511): 100%|| 1/1 [00:01<00:00,  1.66s/it]
# Training (89 / 100 Steps) (loss=0.04025): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (90 / 100 Steps) (loss=0.03092): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (91 / 100 Steps) (loss=0.04984): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (92 / 100 Steps) (loss=0.02663): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (93 / 100 Steps) (loss=0.04911): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (94 / 100 Steps) (loss=0.05421): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (95 / 100 Steps) (loss=0.05416): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (96 / 100 Steps) (loss=0.03145): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (97 / 100 Steps) (loss=0.05027): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (98 / 100 Steps) (loss=0.07011): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (99 / 100 Steps) (loss=0.03707): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (100 / 100 Steps) (loss=0.03023):   0%|| 0/1 [00:01<?, ?it/s]03/20/2025 19:33:51 - INFO - __main__ - ***** Running Validation *****
# 03/20/2025 19:33:51 - INFO - __main__ -   Num steps = 1
# 03/20/2025 19:33:51 - INFO - __main__ -   Batch size = 1024
#
# Validating... (loss=X.X):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.03036):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.03036): 100%|| 1/1 [00:00<00:00,  2.08it/s]
# 03/20/2025 19:33:51 - INFO - __main__ -
#
# 03/20/2025 19:33:51 - INFO - __main__ - Validation Results
# 03/20/2025 19:33:51 - INFO - __main__ - Global Steps: 100
# 03/20/2025 19:33:51 - INFO - __main__ - Valid Loss: 0.03036
# 03/20/2025 19:33:51 - INFO - __main__ - Valid Accuracy: 1.00000
# 03/20/2025 19:33:52 - INFO - __main__ - Saved model checkpoint to [DIR: output/baseline]
# 03/20/2025 19:33:52 - INFO - __main__ - Best model saved at output/baseline/baseline_fold2_checkpoint.bin
# 03/20/2025 19:33:52 - INFO - __main__ - Update best loss from inf to 0.030363
# 03/20/2025 19:33:52 - INFO - __main__ - Update best accuracy from 0.000000 to 1.000000
# Training (100 / 100 Steps) (loss=0.03023):   0%|| 0/1 [00:02<?, ?it/s]
# 03/20/2025 19:33:52 - INFO - __main__ - Best Accuracy: 	1.000000
# 03/20/2025 19:33:52 - INFO - __main__ - Best Loss: 	0.030363
# 03/20/2025 19:33:52 - INFO - __main__ - Done training fold 3
# 03/20/2025 19:33:52 - INFO - __main__ - ===================================
# 03/20/2025 19:33:52 - INFO - __main__ - Training fold: 4 / 5
# Training (1 / 100 Steps) (loss=0.02553): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (2 / 100 Steps) (loss=0.04823): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (3 / 100 Steps) (loss=0.04798): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (4 / 100 Steps) (loss=0.02506): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (5 / 100 Steps) (loss=0.03488): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (6 / 100 Steps) (loss=0.05357): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (7 / 100 Steps) (loss=0.05144): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (8 / 100 Steps) (loss=0.03448): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (9 / 100 Steps) (loss=0.02597): 100%|| 1/1 [00:01<00:00,  1.47s/it]
# Training (10 / 100 Steps) (loss=0.02976): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (11 / 100 Steps) (loss=0.03838): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (12 / 100 Steps) (loss=0.05001): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (13 / 100 Steps) (loss=0.03155): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (14 / 100 Steps) (loss=0.02980): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (15 / 100 Steps) (loss=0.09207): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (16 / 100 Steps) (loss=0.05071): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (17 / 100 Steps) (loss=0.03123): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (18 / 100 Steps) (loss=0.03455): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (19 / 100 Steps) (loss=0.06728): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (20 / 100 Steps) (loss=0.03063): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (21 / 100 Steps) (loss=0.03458): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (22 / 100 Steps) (loss=0.03924): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (23 / 100 Steps) (loss=0.04220): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (24 / 100 Steps) (loss=0.04575): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (25 / 100 Steps) (loss=0.03828): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (26 / 100 Steps) (loss=0.03711): 100%|| 1/1 [00:01<00:00,  1.46s/it]
# Training (27 / 100 Steps) (loss=0.06347): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (28 / 100 Steps) (loss=0.04072): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (29 / 100 Steps) (loss=0.07268): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (30 / 100 Steps) (loss=0.02795): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (31 / 100 Steps) (loss=0.05276): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (32 / 100 Steps) (loss=0.05072): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (33 / 100 Steps) (loss=0.03418): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (34 / 100 Steps) (loss=0.03265): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (35 / 100 Steps) (loss=0.03277): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (36 / 100 Steps) (loss=0.02776): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (37 / 100 Steps) (loss=0.02273): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (38 / 100 Steps) (loss=0.03809): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (39 / 100 Steps) (loss=0.04329): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (40 / 100 Steps) (loss=0.03394): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (41 / 100 Steps) (loss=0.03720): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (42 / 100 Steps) (loss=0.07386): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (43 / 100 Steps) (loss=0.03366): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (44 / 100 Steps) (loss=0.06944): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (45 / 100 Steps) (loss=0.03985): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (46 / 100 Steps) (loss=0.04364): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (47 / 100 Steps) (loss=0.04056): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (48 / 100 Steps) (loss=0.04140): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (49 / 100 Steps) (loss=0.04149): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (50 / 100 Steps) (loss=0.03526): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (51 / 100 Steps) (loss=0.03081): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (52 / 100 Steps) (loss=0.03665): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (53 / 100 Steps) (loss=0.04245): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (54 / 100 Steps) (loss=0.03572): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (55 / 100 Steps) (loss=0.05794): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (56 / 100 Steps) (loss=0.03087): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (57 / 100 Steps) (loss=0.04212): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (58 / 100 Steps) (loss=0.03587): 100%|| 1/1 [00:01<00:00,  1.64s/it]
# Training (59 / 100 Steps) (loss=0.02391): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (60 / 100 Steps) (loss=0.03289): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (61 / 100 Steps) (loss=0.03389): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (62 / 100 Steps) (loss=0.05295): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (63 / 100 Steps) (loss=0.03203): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (64 / 100 Steps) (loss=0.02911): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (65 / 100 Steps) (loss=0.04019): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (66 / 100 Steps) (loss=0.03891): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (67 / 100 Steps) (loss=0.05197): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (68 / 100 Steps) (loss=0.02265): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (69 / 100 Steps) (loss=0.02776): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (70 / 100 Steps) (loss=0.03228): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (71 / 100 Steps) (loss=0.06380): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (72 / 100 Steps) (loss=0.03131): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (73 / 100 Steps) (loss=0.02080): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (74 / 100 Steps) (loss=0.03874): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (75 / 100 Steps) (loss=0.04722): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (76 / 100 Steps) (loss=0.02975): 100%|| 1/1 [00:01<00:00,  1.43s/it]
# Training (77 / 100 Steps) (loss=0.02715): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (78 / 100 Steps) (loss=0.02110): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (79 / 100 Steps) (loss=0.05536): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (80 / 100 Steps) (loss=0.02774): 100%|| 1/1 [00:01<00:00,  1.51s/it]
# Training (81 / 100 Steps) (loss=0.03009): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (82 / 100 Steps) (loss=0.04644): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (83 / 100 Steps) (loss=0.05447): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (84 / 100 Steps) (loss=0.03441): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (85 / 100 Steps) (loss=0.03549): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (86 / 100 Steps) (loss=0.03262): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (87 / 100 Steps) (loss=0.02640): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (88 / 100 Steps) (loss=0.03605): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (89 / 100 Steps) (loss=0.03233): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (90 / 100 Steps) (loss=0.03465): 100%|| 1/1 [00:01<00:00,  1.44s/it]
# Training (91 / 100 Steps) (loss=0.04455): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (92 / 100 Steps) (loss=0.04365): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (93 / 100 Steps) (loss=0.05138): 100%|| 1/1 [00:01<00:00,  1.45s/it]
# Training (94 / 100 Steps) (loss=0.02613): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (95 / 100 Steps) (loss=0.04450): 100%|| 1/1 [00:01<00:00,  1.52s/it]
# Training (96 / 100 Steps) (loss=0.03621): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (97 / 100 Steps) (loss=0.03717): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (98 / 100 Steps) (loss=0.03269): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (99 / 100 Steps) (loss=0.04308): 100%|| 1/1 [00:01<00:00,  1.47s/it]
# Training (100 / 100 Steps) (loss=0.03507):   0%|| 0/1 [00:01<?, ?it/s]03/20/2025 19:36:25 - INFO - __main__ - ***** Running Validation *****
# 03/20/2025 19:36:25 - INFO - __main__ -   Num steps = 1
# 03/20/2025 19:36:25 - INFO - __main__ -   Batch size = 1024
#
# Validating... (loss=X.X):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.02259):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.02259): 100%|| 1/1 [00:00<00:00,  1.94it/s]
# 03/20/2025 19:36:26 - INFO - __main__ -
#
# 03/20/2025 19:36:26 - INFO - __main__ - Validation Results
# 03/20/2025 19:36:26 - INFO - __main__ - Global Steps: 100
# 03/20/2025 19:36:26 - INFO - __main__ - Valid Loss: 0.02259
# 03/20/2025 19:36:26 - INFO - __main__ - Valid Accuracy: 1.00000
# 03/20/2025 19:36:26 - INFO - __main__ - Saved model checkpoint to [DIR: output/baseline]
# 03/20/2025 19:36:26 - INFO - __main__ - Best model saved at output/baseline/baseline_fold3_checkpoint.bin
# 03/20/2025 19:36:26 - INFO - __main__ - Update best loss from inf to 0.022586
# 03/20/2025 19:36:26 - INFO - __main__ - Update best accuracy from 0.000000 to 1.000000
# Training (100 / 100 Steps) (loss=0.03507):   0%|| 0/1 [00:02<?, ?it/s]
# 03/20/2025 19:36:26 - INFO - __main__ - Best Accuracy: 	1.000000
# 03/20/2025 19:36:26 - INFO - __main__ - Best Loss: 	0.022586
# 03/20/2025 19:36:26 - INFO - __main__ - Done training fold 4
# 03/20/2025 19:36:26 - INFO - __main__ - ===================================
# 03/20/2025 19:36:26 - INFO - __main__ - Training fold: 5 / 5
# Training (1 / 100 Steps) (loss=0.05019): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (2 / 100 Steps) (loss=0.03347): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (3 / 100 Steps) (loss=0.02969): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (4 / 100 Steps) (loss=0.03508): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (5 / 100 Steps) (loss=0.07335): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (6 / 100 Steps) (loss=0.03998): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (7 / 100 Steps) (loss=0.06114): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (8 / 100 Steps) (loss=0.05047): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (9 / 100 Steps) (loss=0.03760): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (10 / 100 Steps) (loss=0.05227): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (11 / 100 Steps) (loss=0.07663): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (12 / 100 Steps) (loss=0.02901): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (13 / 100 Steps) (loss=0.06119): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (14 / 100 Steps) (loss=0.04887): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (15 / 100 Steps) (loss=0.04086): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (16 / 100 Steps) (loss=0.06168): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (17 / 100 Steps) (loss=0.03622): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (18 / 100 Steps) (loss=0.03351): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (19 / 100 Steps) (loss=0.03825): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (20 / 100 Steps) (loss=0.03167): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (21 / 100 Steps) (loss=0.03875): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (22 / 100 Steps) (loss=0.05112): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (23 / 100 Steps) (loss=0.02522): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (24 / 100 Steps) (loss=0.04800): 100%|| 1/1 [00:01<00:00,  1.47s/it]
# Training (25 / 100 Steps) (loss=0.03880): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (26 / 100 Steps) (loss=0.03708): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (27 / 100 Steps) (loss=0.05270): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (28 / 100 Steps) (loss=0.04010): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (29 / 100 Steps) (loss=0.04707): 100%|| 1/1 [00:01<00:00,  1.60s/it]
# Training (30 / 100 Steps) (loss=0.05612): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (31 / 100 Steps) (loss=0.04262): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (32 / 100 Steps) (loss=0.03947): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (33 / 100 Steps) (loss=0.04868): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (34 / 100 Steps) (loss=0.04434): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (35 / 100 Steps) (loss=0.04221): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (36 / 100 Steps) (loss=0.03169): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (37 / 100 Steps) (loss=0.04706): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (38 / 100 Steps) (loss=0.03127): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (39 / 100 Steps) (loss=0.03671): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (40 / 100 Steps) (loss=0.06042): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (41 / 100 Steps) (loss=0.04034): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (42 / 100 Steps) (loss=0.07166): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (43 / 100 Steps) (loss=0.02456): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (44 / 100 Steps) (loss=0.02963): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (45 / 100 Steps) (loss=0.03193): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (46 / 100 Steps) (loss=0.05924): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (47 / 100 Steps) (loss=0.03915): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (48 / 100 Steps) (loss=0.03823): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (49 / 100 Steps) (loss=0.03312): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (50 / 100 Steps) (loss=0.04844): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (51 / 100 Steps) (loss=0.05033): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (52 / 100 Steps) (loss=0.05668): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (53 / 100 Steps) (loss=0.03572): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (54 / 100 Steps) (loss=0.04955): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (55 / 100 Steps) (loss=0.04766): 100%|| 1/1 [00:01<00:00,  1.49s/it]
# Training (56 / 100 Steps) (loss=0.02177): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (57 / 100 Steps) (loss=0.02284): 100%|| 1/1 [00:01<00:00,  1.48s/it]
# Training (58 / 100 Steps) (loss=0.04704): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (59 / 100 Steps) (loss=0.04642): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (60 / 100 Steps) (loss=0.03886): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (61 / 100 Steps) (loss=0.04216): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (62 / 100 Steps) (loss=0.02623): 100%|| 1/1 [00:01<00:00,  1.67s/it]
# Training (63 / 100 Steps) (loss=0.03546): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (64 / 100 Steps) (loss=0.06422): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (65 / 100 Steps) (loss=0.04166): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (66 / 100 Steps) (loss=0.04284): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (67 / 100 Steps) (loss=0.05050): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (68 / 100 Steps) (loss=0.06280): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (69 / 100 Steps) (loss=0.04464): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (70 / 100 Steps) (loss=0.03772): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (71 / 100 Steps) (loss=0.03421): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (72 / 100 Steps) (loss=0.06434): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (73 / 100 Steps) (loss=0.03266): 100%|| 1/1 [00:01<00:00,  1.53s/it]
# Training (74 / 100 Steps) (loss=0.05220): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (75 / 100 Steps) (loss=0.03360): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (76 / 100 Steps) (loss=0.04417): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (77 / 100 Steps) (loss=0.02887): 100%|| 1/1 [00:01<00:00,  1.61s/it]
# Training (78 / 100 Steps) (loss=0.03703): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (79 / 100 Steps) (loss=0.04260): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (80 / 100 Steps) (loss=0.07676): 100%|| 1/1 [00:01<00:00,  1.50s/it]
# Training (81 / 100 Steps) (loss=0.04322): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (82 / 100 Steps) (loss=0.06509): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (83 / 100 Steps) (loss=0.03574): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (84 / 100 Steps) (loss=0.04652): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (85 / 100 Steps) (loss=0.03473): 100%|| 1/1 [00:01<00:00,  1.62s/it]
# Training (86 / 100 Steps) (loss=0.04743): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (87 / 100 Steps) (loss=0.03807): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (88 / 100 Steps) (loss=0.04702): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (89 / 100 Steps) (loss=0.04664): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (90 / 100 Steps) (loss=0.04333): 100%|| 1/1 [00:01<00:00,  1.57s/it]
# Training (91 / 100 Steps) (loss=0.03106): 100%|| 1/1 [00:01<00:00,  1.55s/it]
# Training (92 / 100 Steps) (loss=0.03454): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (93 / 100 Steps) (loss=0.03696): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (94 / 100 Steps) (loss=0.02680): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (95 / 100 Steps) (loss=0.02866): 100%|| 1/1 [00:01<00:00,  1.58s/it]
# Training (96 / 100 Steps) (loss=0.04745): 100%|| 1/1 [00:01<00:00,  1.54s/it]
# Training (97 / 100 Steps) (loss=0.04106): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (98 / 100 Steps) (loss=0.04344): 100%|| 1/1 [00:01<00:00,  1.56s/it]
# Training (99 / 100 Steps) (loss=0.04742): 100%|| 1/1 [00:01<00:00,  1.59s/it]
# Training (100 / 100 Steps) (loss=0.01734):   0%|| 0/1 [00:01<?, ?it/s]03/20/2025 19:39:03 - INFO - __main__ - ***** Running Validation *****
# 03/20/2025 19:39:03 - INFO - __main__ -   Num steps = 1
# 03/20/2025 19:39:03 - INFO - __main__ -   Batch size = 1024
#
# Validating... (loss=X.X):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.00730):   0%|| 0/1 [00:00<?, ?it/s]
# Validating... (loss=0.00730): 100%|| 1/1 [00:00<00:00,  2.10it/s]
# 03/20/2025 19:39:03 - INFO - __main__ -
#
# 03/20/2025 19:39:03 - INFO - __main__ - Validation Results
# 03/20/2025 19:39:03 - INFO - __main__ - Global Steps: 100
# 03/20/2025 19:39:03 - INFO - __main__ - Valid Loss: 0.00730
# 03/20/2025 19:39:03 - INFO - __main__ - Valid Accuracy: 1.00000
# 03/20/2025 19:39:04 - INFO - __main__ - Saved model checkpoint to [DIR: output/baseline]
# 03/20/2025 19:39:04 - INFO - __main__ - Best model saved at output/baseline/baseline_fold4_checkpoint.bin
# 03/20/2025 19:39:04 - INFO - __main__ - Update best loss from inf to 0.007304
# 03/20/2025 19:39:04 - INFO - __main__ - Update best accuracy from 0.000000 to 1.000000
# Training (100 / 100 Steps) (loss=0.01734):   0%|| 0/1 [00:02<?, ?it/s]
# 03/20/2025 19:39:04 - INFO - __main__ - Best Accuracy: 	1.000000
# 03/20/2025 19:39:04 - INFO - __main__ - Best Loss: 	0.007304
# 03/20/2025 19:39:04 - INFO - __main__ - Done training fold 5
# 03/20/2025 19:39:04 - INFO - __main__ - ===================================
# 03/20/2025 19:39:04 - INFO - __main__ - All folds done!
# 03/20/2025 19:39:04 - INFO - __main__ - Average Accuracy: 	0.987500
# 03/20/2025 19:39:04 - INFO - __main__ - Average Loss: 	0.038971
# 03/20/2025 19:39:04 - INFO - __main__ - All Paths: ['output/baseline/baseline_fold0_checkpoint.bin', 'output/baseline/baseline_fold1_checkpoint.bin', 'output/baseline/baseline_fold2_checkpoint.bin', 'output/baseline/baseline_fold3_checkpoint.bin', 'output/baseline/baseline_fold4_checkpoint.bin']
# 03/20/2025 19:39:04 - INFO - __main__ - ===================================

# %% [markdown]
# **Baseline**
#
# This baseline is created using the initial setup from the first experimental trial, with most settings left at their default values. Since we do not have access to the test set, we will assess this baseline using the training set. We will employ Stratified K-Fold Cross-Validation with k = 5 to enhance the reliability of our evaluation.
#
# Settings:
# - Training/Evaluation Batch Size: 1024
# - Total Number of Steps: 100
# - Evaluation Frequency: Every 100 steps
# - Warm-Up Steps: 10
# - Learning Rate: 0.03
# - Decay Type: Cosine
# - Data Augmentation Method: RandomResizedCrop
