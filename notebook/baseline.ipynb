# %%
# %cd ..
# !pwd
# Out:
# /remote/vast0/tran/workspace/ViT-pytorch
# /remote/vast0/tran/workspace/ViT-pytorch

# %% [markdown]
# ## 1. Baseline + K-Fold Cross Validation

# %%
# !bash scripts/train.sh
# Out:
# 03/20/2025 21:03:16 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 03/20/2025 21:03:16 - INFO - __main__ - ***** Running training *****
# 03/20/2025 21:03:16 - INFO - __main__ -   Total optimization steps = 150
# 03/20/2025 21:03:16 - INFO - __main__ -   Instantaneous batch size per GPU = 1024
# 03/20/2025 21:03:16 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1024
# 03/20/2025 21:03:16 - INFO - __main__ -   Gradient Accumulation steps = 1
# 03/20/2025 21:03:16 - INFO - __main__ - Training fold: 1 / 5
# 03/20/2025 21:03:17 - INFO - __main__ - classifier: token
# hidden_size: 768
# patches:
#   size: !!python/tuple
#   - 16
#   - 16
# representation_size: null
# transformer:
#   attention_dropout_rate: 0.0
#   dropout_rate: 0.1
#   mlp_dim: 3072
#   num_heads: 12
#   num_layers: 12
#
# ...

# %% [markdown]
# **Baseline**
#
# This baseline is created using the initial setup from the first experimental trial, with most settings left at their default values. Since we do not have access to the test set, we will assess this baseline using the training set. We will employ Stratified K-Fold Cross-Validation with k = 5 to enhance the reliability of our evaluation.
#
# Settings:
# - Training/Evaluation Batch Size: 1024
# - Total Number of Steps: 100
# - Evaluation Frequency: Every 100 steps
# - Warm-Up Steps: 10
# - Learning Rate: 0.03
# - Decay Type: Cosine
# - Data Augmentation Method: RandomResizedCrop
